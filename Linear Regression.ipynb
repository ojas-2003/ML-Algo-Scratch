# %%
pip install plotly
# Out:
# ...
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/d6/54/a8759957b778094233d7058c8ddbe368504b448ffe9c26a85f7bfd53584e/plotly-5.16.0-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB 1.9 MB/s eta 0:00:09
#    ---------------------------------------- 0.2/15.6 MB 2.4 MB/s eta 0:00:07
#     --------------------------------------- 0.4/15.6 MB 3.3 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/15.6 MB 3.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.7/15.6 MB 3.9 MB/s eta 0:00:04
#    -- ------------------------------------- 1.0/15.6 MB 4.3 MB/s eta 0:00:04
#    --- ------------------------------------ 1.2/15.6 MB 4.4 MB/s eta 0:00:04
#    --- ------------------------------------ 1.4/15.6 MB 4.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/15.6 MB 4.8 MB/s eta 0:00:03
# ...

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import plotly.express as px

# %%
train = pd.read_csv("../scratch algo/dataset/LRdata/train.csv")
test = pd.read_csv("../scratch algo/dataset/LRdata/test.csv")
# test.isnull().sum()
train = train.dropna()
test = test.dropna()

# %%
train.shape
# Out:
# (699, 2)

# %%
px.scatter(x=train['x'], y=train['y'], template="seaborn")
# Out:
# <div>                            <div id="e46d89f2-adc4-4b3f-b37e-84ba67687827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e46d89f2-adc4-4b3f-b37e-84ba67687827")) {                    Plotly.newPlot(                        "e46d89f2-adc4-4b3f-b37e-84ba67687827",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"rgb(76,114,176)","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[24.0,50.0,15.0,38.0,87.0,36.0,12.0,81.0,25.0,5.0,16.0,16.0,24.0,39.0,54.0,60.0,26.0,73.0,29.0,31.0,68.0,87.0,58.0,54.0,84.0,58.0,49.0,20.0,90.0,48.0,4.0,25.0,42.0,0.0,60.0,93.0,39.0,7.0,21.0,68.0,84.0,0.0,58.0,19.0,36.0,19.0,59.0,51.0,19.0,
# ...

# %%
x_train = train['x'].values
y_train = train['y'].values

x_test = test['x'].values
y_test = test['y'].values
x_train.shape
# Out:
# (699,)

# %%
mean = np.mean(x_train, axis=0)
std = np.std(x_train, axis=0)

x_train = (x_train-mean)/std
x_test = (x_test-mean)/std

# %%
class LinearRegression:
    def __init__(self, learning_rate):
        self.learning_rate = learning_rate
        
    def init_parametes(self):
        if self.X.ndim==1:
            self.W=0
        else:
            self.W= self.W= n.random.randn(self.X.shape[-1])
        print(self.X.shape[-1])
        self.b=0
    def forward(self, X):
        z= np.dot(X, self.W)+self.b
        return z
    def cost(self, predictions, y):
        m=len(self.X)
        j=np.sum(np.square(np.subtract(predictions, y)))
        j=j*1/(2*m)
        return j
    def backward(self, predictions):
        m=len(self.X)
        self.db=1/m*np.sum(predictions-self.y)
        self.dw = 1/m*np.dot((predictions-self.y), self.X)

    def fit(self, x, y, iterations, plot_cost=True):
        costarr=[]
        self.X=x
        self.y=y
        self.init_parametes()
        for i in range(iterations):
            z= self.forward(self.X)
            cost = self.cost(z, self.y)
            costarr.append(cost)
            self.backward(z)

            self.W = self.W- self.learning_rate*self.dw
            self.b = self.b - self.learning_rate*self.db
#         if plot_cost:
#             fig = px.line(y=cost, title="cost vs iterations", template = "plotly_dark")
#             fig.update_layout(
#                 title_font_color = "#41BEE9",
#                 xaxis = dict(color="#41BEE9", title="Iterations"),
#                 yaxis= dict(color = "#41BEE9", title="cost"),
#             )

#             fig.show()
    def predict(self, X):
        pred = self.forward(X)
        return pred

# %%
lr =LinearRegression(0.01)
lr.fit(x_train, y_train, 10000)
# Out:
# 699

# %%
preds = lr.predict(x_test)
lr.cost(preds, y_test)
# Out:
# 2.0242322300514357

# %%
preds
# Out:
# array([76.94327594, 20.90651855, 21.90717494, 19.90586217, 35.91636428,
#        14.90258026, 61.93343021, 94.95509081, 19.90586217,  4.89601644,
#         3.89536006, 18.90520579, 95.95574719, 61.93343021, 35.91636428,
#        14.90258026, 64.93539936, 13.90192388, 86.94983976, 68.93802488,
#        88.95115252, 50.92621001, 88.95115252, 26.91045685, 96.95640358,
#        57.93080468, 78.9445887 , 20.90651855, 92.95377805, 26.91045685,
#        98.95771634, 30.91308237, 32.91439514, 79.94524508, 27.91111323,
#        46.92358448, 52.92752277, 68.93802488, 27.91111323, 32.91439514,
#        90.95246528, 70.93933765, 49.92555363, 75.94261956,  3.89536006,
#        36.91702066, 69.93868127, 67.9373685 , 39.91898981, 34.9157079 ,
#        93.95443443, 87.95049614, 51.92686639, 30.91308237, 58.93146107,
#        -0.10726546, 38.91833343, 63.93474297, 68.93802488, 56.9301483 ,
#        12.9012675 , 71.93999403, 75.94261956, 60.93277383, 81.94655785,
# ...
